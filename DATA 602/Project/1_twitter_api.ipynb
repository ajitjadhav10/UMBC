# %% [markdown]
# <a href="https://colab.research.google.com/github/ajitjadhav10/UMBC/blob/main/DATA%20602/Project/1_twitter_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/dist-packages (3.10.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.3.1)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)

# %%
pip install configparser
# Out:
# Collecting configparser
#   Downloading configparser-5.2.0-py3-none-any.whl (19 kB)
# Installing collected packages: configparser
# Successfully installed configparser-5.2.0

# %%
import tweepy
import configparser
import pandas as pd

# %%
#read the credentials from the config file


config = configparser.ConfigParser()
config.read('config.ini')
# Out:
# ['config.ini']

# %%
api_key=config['twitter']['api_key']
api_key_secret=config['twitter']['api_key_secret']

access_token=config['twitter']['access_token']
access_token_secret=config['twitter']['access_token_secret']

# %%
print(api_key)
# Out:
# 3FSMC4CUHUvoGDzbi5DSiJqdp

# %%
#authentication

auth=tweepy.OAuthHandler(api_key,api_key_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
api=tweepy.API(auth)

# %%
public_tweets=api.home_timeline()

# %%
columns=['Time','User','Tweet']

# %%
data=[]

# %%
for tweet in public_tweets:
  data.append([tweet.created_at,tweet.user.screen_name,tweet.text])

# %%
print(data)
# Out:
# [[datetime.datetime(2022, 4, 18, 16, 31, 16), 'boogiepest', 'RT @kbschroedy: @DaShaunLH This one is my favorite https://t.co/o9JOQsSWbL'], [datetime.datetime(2022, 4, 18, 16, 30, 16), 'TheFunnyVine', 'RT @TheDegenWeekly: Almost to 1000 followers. Probably because we’ve been crushing MLB, and people like winners! \n\nIf we get to 1500 follow…'], [datetime.datetime(2022, 4, 18, 16, 30, 15), 'Blockworks_', 'Registered digital securities will replace the current financial legacy system, Digital Funds’ founder says\n\nVia… https://t.co/O6Ri5ibc6P'], [datetime.datetime(2022, 4, 18, 16, 30, 14), 'kdnuggets', 'The Complete #DataScience #LinkedIn Profile Guide #KDnuggets https://t.co/yTDLzFLhZN'], [datetime.datetime(2022, 4, 18, 16, 30, 7), 'discountsdeck', 'Avail 43% Off On AmazonBasics Zero Gravity Reclining Lounge Portable Chair\n\nMRP: Rs 6,000\n\nDeal Price: Rs 3,439 (Ex… https://t.co/fqWYkOXo5C'], [datetime.datetime(2022, 4, 18, 16, 30, 1), 'TDataScience', "If you'd like to get a better grasp of forecasting methods, here's Benjamin McCloskey's demonstration, using the pr… https://t.co/L2pQtxrGws"], [datetime.datetime(2022, 4, 18, 16, 29, 59), 'boogiepest', 'RT @The_lst_0ne: @DaShaunLH This the best one.\nAnd you learn somthing 😅 https://t.co/G0MSY50xhw'], [datetime.datetime(2022, 4, 18, 16, 27, 14), 'TechInsider', 'This system combines fish farming and hydroponics for growing food https://t.co/YZL92DvLXn'], [datetime.datetime(2022, 4, 18, 16, 25, 55), 'MomentsIndia', 'On Monday, @josbuttler fans were in for a treat as the @rajasthanroyals opener scored his second century of… https://t.co/ovZpeDUIaf'], [datetime.datetime(2022, 4, 18, 16, 25, 26), 'PyTorch', 'RT @srush_nlp: Do you (really) know PyTorch 🔥?\n\nTry out my Tensor Puzzles 🧩. 16 mini-puzzles for those ready to take off the stackoverflow…'], [datetime.datetime(2022, 4, 18, 16, 25, 8), 'krownnist', 'get your fucking ass up and love with all your heart. it seems like nobody wants to love with all their heart these days'], [datetime.datetime(2022, 4, 18, 16, 24, 13), 'ESPNcricinfo', "Delhi Capitals' Mitchell Marsh has been admitted to a hospital after he tested positive for Covid\n\n#IPL2022 https://t.co/NNINukKVp4"], [datetime.datetime(2022, 4, 18, 16, 24), 'boogiepest', 'RT @seunisking: @DaShaunLH The best one IMO https://t.co/hTp3tVha7o'], [datetime.datetime(2022, 4, 18, 16, 23, 16), 'boogiepest', 'RT @DaShaunLH: idk if this one will be as funny to y’all as it is to me, but i hollered 🤣 https://t.co/A8Pe6hx8F9'], [datetime.datetime(2022, 4, 18, 16, 22, 27), 'boogiepest', 'RT @DaShaunLH: this is the first video i saw and there were real tears in my eyes 😭😭😭😭 https://t.co/Uk8yGoFEWG'], [datetime.datetime(2022, 4, 18, 16, 15, 40), 'zoo_bear', 'सोशल मीडिया पर पवन हंस के इंटर्न्स की एक लिस्ट वायरल है जिसे शेयर करते हुए ये दावा किया जा रहा है कि कंपनी ने हि… https://t.co/1oCp5rQYAz'], [datetime.datetime(2022, 4, 18, 16, 14, 53), 'AJA_Cortes', 'You feel IMPOSTER SYNDROME because you want the Future to prove your Past\n\nYou want to change, but you doubt your a… https://t.co/plgAsQElWz'], [datetime.datetime(2022, 4, 18, 16, 13, 51), 'driscollis', "I personally think it's awesome that I can work with\n\n🐍 XML\n🐍 JSON\n🐍 CSV\n🐍 Zip / Tar files\n\nand more without installing anything!"], [datetime.datetime(2022, 4, 18, 16, 13, 51), 'driscollis', 'Which #Python packages were you surprised were included in the standard library?'], [datetime.datetime(2022, 4, 18, 16, 12, 30), 'ESPNcricinfo', 'Sunil Narine was sent up the order as an opener today\n\nAnd Shimron Hetmyer runs him out with a direct hit 🎯 #RRvKKR… https://t.co/Qtw5PWgzS8']]

# %%
df=pd.DataFrame(data,columns=columns)
df.head()
# Out:
#                  Time           User  \
# 0 2022-04-18 16:31:16     boogiepest
# 1 2022-04-18 16:30:16   TheFunnyVine
# 2 2022-04-18 16:30:15    Blockworks_
# 3 2022-04-18 16:30:14      kdnuggets
# 4 2022-04-18 16:30:07  discountsdeck
#
#                                                Tweet
# 0  RT @kbschroedy: @DaShaunLH This one is my favo...
# 1  RT @TheDegenWeekly: Almost to 1000 followers. ...
# 2  Registered digital securities will replace the...
# 3  The Complete #DataScience #LinkedIn Profile Gu...
# 4  Avail 43% Off On AmazonBasics Zero Gravity Rec...

# %%
df.to_csv('tweets.csv')

# %%
print(public_tweets)
# Out:
# [Status(_api=<tweepy.api.API object at 0x7f57003234d0>, _json={'created_at': 'Mon Apr 18 16:31:16 +0000 2022', 'id': 1516092004480221187, 'id_str': '1516092004480221187', 'text': 'RT @kbschroedy: @DaShaunLH This one is my favorite https://t.co/o9JOQsSWbL', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'kbschroedy', 'name': 'Kate Schroeder', 'id': 412662979, 'id_str': '412662979', 'indices': [3, 14]}, {'screen_name': 'DaShaunLH', 'name': 'Da’Shaun | they/them', 'id': 171266507, 'id_str': '171266507', 'indices': [16, 26]}], 'urls': [], 'media': [{'id': 1516048166327574530, 'id_str': '1516048166327574530', 'indices': [51, 74], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1516048166327574530/pu/img/9lDzSIaJuNYThHas.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1516048166327574530/pu/img/9lDzSIaJuNYThHas.jpg', 'url': 'https://t.co/o9JOQsSWbL', 'display_url': 'pic.twitter.com/o9JOQsSWbL', 'expanded_url': 'https://twitter.com/kbschroedy/status/1516048186535821313/video/1', 'type': 'photo', 'sizes': {'large': {'w': 576, 'h': 1080, 'resize': 'fit'}, 'small': {'w': 363, 'h': 680, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 576, 'h': 1080, 'resize': 'fit'}}, 'source_status_id': 1516048186535821313, 'source_status_id_str': '1516048186535821313', 'source_user_id': 412662979, 'source_user_id_str': '412662979'}]}, 'extended_entities': {'media': [{'id': 1516048166327574530, 'id_str': '1516048166327574530', 'indices': [51, 74], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1516048166327574530/pu/img/9lDzSIaJuNYThHas.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1516048166327574530/pu/img/9lDzSIaJuNYThHas.jpg', 'url': 'https://t.co/o9JOQsSWbL', 'display_url': 'pic.twitter.com/o9JOQsSWbL', 'expanded_url': 'https://twitter.com/kbschroedy/status/1516048186535821313/video/1', 'type': 'video', 'sizes': {'large': {'w': 576, 'h': 1080, 'resize': 'fit'}, 'small': {'w': 363, 'h': 680, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 576, 'h': 1080, 'resize': 'fit'}}, 'source_status_id': 1516048186535821313, 'source_status_id_str': '1516048186535821313', 'source_user_id': 412662979, 'source_user_id_str': '412662979', 'video_info': {'aspect_ratio': [8, 15], 'duration_millis': 11433, 'variants': [{'content_type': 'application/x-mpegURL', 'url': 'https://video.twimg.com/ext_tw_video/1516048166327574530/pu/pl/90J1P3UriegwrEZb.m3u8?tag=12&container=fmp4'}, {'bitrate': 950000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1516048166327574530/pu/vid/480x900/yxqV4rSp0Abcrb64.mp4?tag=12'}, {'bitrate': 2176000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1516048166327574530/pu/vid/576x1080/qbZnQTZEEvcg1gdn.mp4?tag=12'}, {'bitrate': 632000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1516048166327574530/pu/vid/320x600/y_gnvZKF3udTi49a.mp4?tag=12'}]}, 'additional_media_info': {'monetizable': False, 'source_user': {'id': 412662979, 'id_str': '412662979', 'name': 'Kate Schroeder', 'screen_name': 'kbschroedy', 'location': '', 'description': 'iron deficient', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1481, 'friends_count': 716, 'listed_count': 19, 'created_at': 'Tue Nov 15 00:36:54 +0000 2011', 'favourites_count': 72806, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 21346, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1511025780003909642/3PUQ_W0J_ ...

# %%
print(public_tweets[0].user.screen_name)
# Out:
# boogiepest

# %%
# for tweet in public_tweets:
#   print(tweet.text)
# Out:
# RT @kbschroedy: @DaShaunLH This one is my favorite https://t.co/o9JOQsSWbL
# RT @TheDegenWeekly: Almost to 1000 followers. Probably because we’ve been crushing MLB, and people like winners!
#
# If we get to 1500 follow…
# Registered digital securities will replace the current financial legacy system, Digital Funds’ founder says
#
# Via… https://t.co/O6Ri5ibc6P
# The Complete #DataScience #LinkedIn Profile Guide #KDnuggets https://t.co/yTDLzFLhZN
# Avail 43% Off On AmazonBasics Zero Gravity Reclining Lounge Portable Chair
#
# MRP: Rs 6,000
#
# Deal Price: Rs 3,439 (Ex… https://t.co/fqWYkOXo5C
# If you'd like to get a better grasp of forecasting methods, here's Benjamin McCloskey's demonstration, using the pr… https://t.co/L2pQtxrGws
# RT @The_lst_0ne: @DaShaunLH This the best one.
# And you learn somthing 😅 https://t.co/G0MSY50xhw
# This system combines fish farming and hydroponics for growing food https://t.co/YZL92DvLXn
# On Monday, @josbuttler fans were in for a treat as the @rajasthanroyals opener scored his second century of… https://t.co/ovZpeDUIaf
# RT @srush_nlp: Do you (really) know PyTorch 🔥?
#
# Try out my Tensor Puzzles 🧩. 16 mini-puzzles for those ready to take off the stackoverflow…
# get your fucking ass up and love with all your heart. it seems like nobody wants to love with all their heart these days
# Delhi Capitals' Mitchell Marsh has been admitted to a hospital after he tested positive for Covid
#
# #IPL2022 https://t.co/NNINukKVp4
# RT @seunisking: @DaShaunLH The best one IMO https://t.co/hTp3tVha7o
# RT @DaShaunLH: idk if this one will be as funny to y’all as it is to me, but i hollered 🤣 https://t.co/A8Pe6hx8F9
# RT @DaShaunLH: this is the first video i saw and there were real tears in my eyes 😭😭😭😭 https://t.co/Uk8yGoFEWG
# सोशल मीडिया पर पवन हंस के इंटर्न्स की एक लिस्ट वायरल है जिसे शेयर करते हुए ये दावा किया जा रहा है कि कंपनी ने हि… https://t.co/1oCp5rQYAz
# You feel IMPOSTER SYNDROME because you want the Future to prove your Past
#
# You want to change, but you doubt your a… https://t.co/plgAsQElWz
# I personally think it's awesome that I can work with
#
# 🐍 XML
# 🐍 JSON
# 🐍 CSV
# 🐍 Zip / Tar files
#
# and more without installing anything!
# Which #Python packages were you surprised were included in the standard library?
# Sunil Narine was sent up the order as an opener today
#
# And Shimron Hetmyer runs him out with a direct hit 🎯 #RRvKKR… https://t.co/Qtw5PWgzS8
